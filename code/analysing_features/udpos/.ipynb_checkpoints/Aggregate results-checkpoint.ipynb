# %%
import os, pandas as pd
os.listdir("results/")
# Out:
# ['.ipynb_checkpoints',
#  'dev_results_af.txt',
#  'dev_results_ar.txt',
#  'dev_results_bg.txt',
#  'dev_results_de.txt',
#  'dev_results_el.txt',
#  'dev_results_en.txt',
#  'dev_results_es.txt',
#  'dev_results_et.txt',
#  'dev_results_eu.txt',
#  'dev_results_fa.txt',
#  'dev_results_fi.txt',
#  'dev_results_fr.txt',
#  'dev_results_he.txt',
#  'dev_results_hi.txt',
#  'dev_results_hu.txt',
#  'dev_results_id.txt',
#  'dev_results_it.txt']

# %%
results = {"train_lang":[],"test_lang":[],"acc":[],"f1":[]}
for file in os.listdir("results/"):
    if "dev_results" in file:
        train_lang = file.split("_")[2][:2]
        with open(f"results/{file}") as f:
            lines = f.read().split("\n")
            f.close()

        for line in lines:
            if "language" in line:
                language = line.split("=")[1]
                results["test_lang"].append(language)
                results["train_lang"].append(train_lang)
            elif "accuracy" in line:
                accuracy = line.split()[2]
                results["acc"].append(float(accuracy))
            elif "f1" in line:
                f1 = line.split()[2]
                results["f1"].append(float(f1))
            else:
                continue

# %%
results_df = pd.DataFrame.from_dict(results)

# %%
results_df
# Out:
#     train_lang test_lang       acc        f1
# 0           af        af  0.984390  0.982330
# 1           af        ar  0.587932  0.517718
# 2           af        bg  0.847598  0.834094
# 3           af        de  0.837953  0.828865
# 4           af        el  0.800967  0.779682
# 5           af        en  0.859992  0.841356
# 6           af        es  0.861089  0.843401
# 7           af        et  0.862722  0.829340
# 8           af        eu  0.753600  0.699914
# 9           af        fa  0.711774  0.641261
# 10          af        fi  0.824476  0.791837
# 11          af        fr  0.512765  0.497371
# 12          af        he  0.734147  0.666850
# 13          af        hi  0.721725  0.671587
# 14          af        hu  0.779383  0.732360
# 15          af        id  0.773153  0.725613
# 16          af        it  0.854534  0.839584
# 17          af        ja  0.194476  0.126619
# 18          af        ko  0.584891  0.468376
# 19          af        mr  0.835000  0.785100
# 20          af        nl  0.858270  0.841876
# 21          af        pt  0.840885  0.827069
# 22          af        ru  0.853383  0.831038
# 23          af        ta  0.727192  0.648109
# 24          af        te  0.812689  0.772803
# 25          af        tr  0.732536  0.668156
# 26          af        ur  0.680063  0.598947
# 27          af        vi  0.577905  0.506880
# 28          af        zh  0.248914  0.158468
# 29          ar        af  0.712996  0.673989
# ..         ...       ...       ...       ...
# 434         id        zh  0.352918  0.250406
# 435         it        af  0.863457  0.851657
# 436         it        ar  0.670592  0.606419
# 437         it        bg  0.906271  0.896134
# 438         it        de  0.845694  0.837015
# 439         it        el  0.847815  0.834292
# 440         it        en  0.881371  0.869442
# 441         it        es  0.943357  0.937106
# 442         it        et  0.878899  0.845085
# 443         it        eu  0.764142  0.696183
# 444         it        fa  0.776198  0.710130
# 445         it        fi  0.861170  0.830460
# 446         it        fr  0.568335  0.554858
# 447         it        he  0.776262  0.714571
# 448         it        hi  0.743902  0.675694
# 449         it        hu  0.856717  0.807692
# 450         it        id  0.846654  0.803099
# 451         it        it  0.975661  0.972390
# 452         it        ja  0.360547  0.286145
# 453         it        ko  0.612552  0.487375
# 454         it        mr  0.822500  0.756133
# 455         it        nl  0.904264  0.887324
# 456         it        pt  0.926385  0.920248
# 457         it        ru  0.906117  0.890986
# 458         it        ta  0.757307  0.665259
# 459         it        te  0.844411  0.811570
# 460         it        tr  0.788995  0.731078
# 461         it        ur  0.740278  0.641900
# 462         it        vi  0.611777  0.540594
# 463         it        zh  0.450644  0.335125
#
# [464 rows x 4 columns]
