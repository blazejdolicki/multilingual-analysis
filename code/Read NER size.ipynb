# %%
import pandas as pd
df = pd.read_csv('ner_size.tex',
                 sep='&',
                 header=None)

# %%
df = df[[0,1,2]]
df.columns = ["lang","# train sentences (in k)","# test sentences (in k)"]

# %%
df.lang = df.lang.str.strip()

# %%
df
# Out:
#    lang  # train sentences (in k)  # test sentences (in k)
# 0    af                         5                        1
# 1    ar                        20                       10
# 2    bg                        20                       10
# 3    bn                        10                        1
# 4    bs                        15                        1
# 5    ca                        20                       10
# 6    cs                        20                       10
# 7    da                        20                       10
# 8    de                        20                       10
# 9    el                        20                       10
# 10   en                        20                       10
# 11   es                        20                       10
# 12   et                        15                       10
# 13   fa                        20                       10
# 14   fi                        20                       10
# ...
